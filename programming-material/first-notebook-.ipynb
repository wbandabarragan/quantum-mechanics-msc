# %% [markdown]
# # Test notebook:
#
# ### W. Banda-Barragán
#
# Open it on Google Colab or in your own Conda installations.

# %% [markdown]
# ## 1) Check where we are, we can use bash commands in a jupyter notebook with "!" e.g.

# %%
# !pwd
# Out:
# /Users/webb/Dropbox/Yachay_Tech/NANOPHYS/nanophys-visualizacion-cientifica

# %% [markdown]
# ## 2) Check the python version:

# %%
# !python --version
# Out:
# Python 3.7.10

# %% [markdown]
# ## 3) Now, let's import a few libraries, there should be no errors:

# %%
# Importing libraries, note that "#" can be used to comment your code
import numpy as np
import matplotlib.pyplot as plt

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## 4) Now, let's make a simple plot:

# %%
# We add this line so we can actually see the plot on our screen
# %matplotlib inline

x = np.arange(-np.pi,np.pi,0.01)

print(x.size) # SIZE OF VECTOR
print(x.shape) 
print(x[0])
# Out:
# 629
# (629,)
# -3.141592653589793

# %% [markdown]
# ### Second way:

# %%
x = np.linspace(-np.pi,np.pi,629)

# %%
print(x.size) # SIZE OF VECTOR
print(x.shape) 
print(x[0])
# Out:
# 629
# (629,)
# -3.141592653589793

# %% [markdown]
# ### Plotting:

# %%
# We add this line so we can actually see the plot on our screen
# %matplotlib inline

y1 = np.sin(x)

y2 = np.cos(x)

y3 = x

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

# %% [markdown]
# ## 5) Now, let us do some fancy plots, e.g. for equation:
#
# $z = \sin(\sqrt{x^2+y^2})$

# %%
# Let's define a function:

def f(x, y):  # Which we can call later on
    return np.sin(np.sqrt(x ** 2 + y ** 2)) # Must be indented

x = np.linspace(-10, 10, 30)  # Define x coordinates
y = np.linspace(-10, 10, 30)  # Define y coordinates

X, Y = np.meshgrid(x, y)  #Create the grid, i.e., from vector coordinates, it generates a matrix of coordinates

print(x.shape, X.shape, y.shape, Y.shape)

Z = f(X, Y) # Call function and get Z
# Out:
# (30,) (30, 30) (30,) (30, 30)

# %%
# Now we do some plotting:
fig = plt.figure()

ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 100, cmap='viridis') # Creates 'n=100' contours at different Z to make the surface

ax.set_xlabel('x')  # Customised labels for axes
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
# Now we do some plotting:
fig = plt.figure()

ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 10, cmap='Blues') # Creates 'n=10' contours at different Z to make the surface

ax.set_xlabel('x')  # Customised labels for axes
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')
